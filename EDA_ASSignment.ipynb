# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Cardiotocographic.csv')
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean=df['LB'].mean()

# %%
mode=df['AC'].mode()

# %%
df.fillna({'LB':mean,'AC':mode[0]},inplace=True)

# %%
df.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean=df['DS'].mean()

# %%
mean=df['DP'].mean()

# %%
mean=df['MLTV'].mean()

# %%
mode=df['Width'].mode()
mode=df['Tendency'].mode()
mode=df['NSP'].mode()

# %%
df.fillna({'DS':mean,'DP':mean,'MLTV':mean,'Width':mode[0],'Tendency':mode[0],'NSP':mode[0]},inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean    133.342039     0.003189     0.009904     0.004394     0.001897
# std      11.212396     0.004382     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001572     0.000000     0.004486     0.000000
# 75%     140.000000     0.005612     0.002568     0.006536     0.003292
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean      0.081915     0.082086    47.012459     1.364345    10.295650
# std       0.819905     0.819888    18.812403     1.174084    21.212676
# ...

# %%
df.boxplot()
plt.show()

# %%
## Outlier_capping using IQR Method
def outlier_capping(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_bound= Q1-1.5*IQR
    upper_bound= Q3+1.5*IQR
    df[column]= df[column].apply(lambda x:lower_bound if x<lower_bound else upper_bound if x>upper_bound else x)
for col in df.select_dtypes(['int','float']).columns:
    outlier_capping(df,col)

# %%
df.boxplot()
plt.show()

# %%
#  histoplat for numerical columns

import matplotlib.pyplot as plt
df.hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
## barcharts for  numericals columns
sns.barplot(figsize=(15, 10))

plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2124 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2124 non-null   float64
#  1   AC        2124 non-null   float64
#  2   FM        2124 non-null   float64
#  3   UC        2124 non-null   float64
#  4   DL        2124 non-null   float64
#  5   DS        2124 non-null   float64
#  6   DP        2124 non-null   float64
#  7   ASTV      2124 non-null   float64
#  8   MSTV      2124 non-null   float64
#  9   ALTV      2124 non-null   float64
#  10  MLTV      2124 non-null   float64
#  11  Width     2124 non-null   float64
#  12  Tendency  2124 non-null   float64
#  13  NSP       2124 non-null   float64
# dtypes: float64(14)
# memory usage: 248.9 KB

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index([], dtype='object')

# %%
for col in categorical_cols:
    plt.figure(figsize(10,6))
    df[col].value_counts().plot(kind='bar')
    plt.title('Frequency of Categorical columns',size=15,weight='bold',color='blue')
    plt.xlabel(col,size=15,weight='bold',color='red')
    plt.ylabel('Frequency',size=15,weight='bold',color='green')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
for col in categorical_cols:
    plt.figure(figsize=(10,6))
    df[col].value_counts().plot(kind='bar')
    plt.title('Frequency of Categorical columns',size=15,weight='bold',color='blue')
    plt.xlabel(col,size=15,weight='bold',color='red')
    plt.ylabel('Frequency',size=15,weight='bold',color='green')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
for col in categorical_cols:
    plt.figure(figsize=(8, 8))
    df[col].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Distribution of {col}', size=15, weight='bold', color='blue')
    plt.ylabel('') # Remove the default ylabel for pie chart
    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df_clean = df[df['NSP'].isin([1, 2, 3])]

# %%
nsp_counts = df_clean['NSP'].value_counts().sort_index()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=nsp_counts.index.astype(str), y=nsp_counts.values, palette="pastel")
plt.title("Cleaned Frequency of Fetal States (NSP)")
plt.xlabel("Fetal State (1=Normal, 2=Suspect, 3=Pathologic)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
sns.violinplot(data=df_clean, x='NSP', y='ASTV',palette='Set3')
plt.title('Distribution of  ASTV across NSP Classes')
plt.xlabel('NSP Class')
plt.ylabel('ASTV')
plt.legend()
plt.show()

# %%
corelation =df.corr()

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
plt.show()
